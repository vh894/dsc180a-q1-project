# %%
import requests
import pandas as pd

# %%
api_key = 'GvRS2pLezm98pu7roQKuv4E44GL0akiMrKa1q9Yc'
station_url = f'https://developer.nrel.gov/api/alt-fuel-stations/v1.json?api_key={api_key}&fuel_type=ELEC'

# %%
request = requests.get(station_url)

# %%
data = request.content
with open('afdc_data.json', 'wb') as f:
    f.write(data)

# %%
x = request.json()

# %%
df = pd.DataFrame(x['fuel_stations']) 
df = df.set_index('station_name')
df = df[df.get('state') == 'CA']
df
# Out:
#                                   access_code  \
# station_name
# LADWP - Truesdale Center              private
# Los Angeles Convention Center          public
# LADWP - John Ferraro Building         private
# LADWP - Haynes Power Plant            private
# LADWP - Harbor Generating Station     private
# ...                                       ...
# DELANO CHEVY STATION 4                 public
# DELANO CHEVY STATION 5                 public
# DELANO CHEVY STATION 6                 public
# SCT PARKING SCT EV CHARGER             public
# Santa Fe Springs Marketplace           public
#
#                                                   access_days_time  \
# station_name
# LADWP - Truesdale Center                            Fleet use only
# Los Angeles Convention Center                  5:30am-9pm; pay lot
# LADWP - John Ferraro Building      For fleet and employee use only
# LADWP - Haynes Power Plant                          Fleet use only
# LADWP - Harbor Generating Station                   Fleet use only
# ...                                                            ...
# DELANO CHEVY STATION 4                              24 hours daily
# DELANO CHEVY STATION 5                              24 hours daily
# DELANO CHEVY STATION 6                              24 hours daily
# SCT PARKING SCT EV CHARGER                          24 hours daily
# Santa Fe Springs Marketplace                        24 hours daily
#
#                                   access_detail_code cards_accepted  \
# station_name
# LADWP - Truesdale Center                        None           None
# Los Angeles Convention Center                   None           None
# LADWP - John Ferraro Building                   None           None
# LADWP - Haynes Power Plant                      None           None
# LADWP - Harbor Generating Station               None           None
# ...                                              ...            ...
# DELANO CHEVY STATION 4                          None           None
# DELANO CHEVY STATION 5                          None           None
# DELANO CHEVY STATION 6                          None           None
# SCT PARKING SCT EV CHARGER                      None           None
# Santa Fe Springs Marketplace                    None           None
#
#                                   date_last_confirmed expected_date  \
# station_name
# LADWP - Truesdale Center                   2023-09-14          None
# Los Angeles Convention Center              2023-01-10          None
# LADWP - John Ferraro Building              2023-09-14          None
# LADWP - Haynes Power Plant                 2024-01-09          None
# LADWP - Harbor Generating Station          2024-01-09          None
# ...                                               ...           ...
# DELANO CHEVY STATION 4                     2024-10-14          None
# DELANO CHEVY STATION 5                     2024-10-14    2024-10-12
# DELANO CHEVY STATION 6                     2024-10-14          None
# SCT PARKING SCT EV CHARGER                 2024-10-14          None
# Santa Fe Springs Marketplace               2024-10-13          None
#
#                                   fuel_type_code  \
# station_name
# LADWP - Truesdale Center                    ELEC
# Los Angeles Convention Center               ELEC
# LADWP - John Ferraro Building               ELEC
# LADWP - Haynes Power Plant                  ELEC
# LADWP - Harbor Generating Station           ELEC
# ...                                          ...
# DELANO CHEVY STATION 4                      ELEC
# DELANO CHEVY STATION 5                      ELEC
# DELANO CHEVY STATION 6                      ELEC
# SCT PARKING SCT EV CHARGER                  ELEC
# Santa Fe Springs Marketplace                ELEC
#
#                                             groups_with_access_code      id  \
# station_name
# LADWP - Truesdale Center                                    Private    1517
# Los Angeles Convention Center                                Public    1523
# LADWP - John Ferraro Building                               Private    1525
# LADWP - Haynes Power Plant                                  Private    1531
# LADWP - Harbor Generating Station                           Private    1552
# ...                                                             ...     ...
# DELANO CHEVY STATION 4                                       Public  357923
# DELANO CHEVY STATION 5             TEMPORARILY UNAVAILABLE (Public)  357924
# DELANO CHEVY STATION 6                                       Public  357925
# SCT PARKING SCT EV CHARGER                                   Public  357933
# Santa Fe Springs Marketplace                                 Public  357962
#
#                                   maximum_vehicle_class  ... rd_blends_fr  \
# station_name                                             ...
# LADWP - Truesdale Center                           None  ...         None
# Los Angeles Convention Center                        LD  ...         None
# LADWP - John Ferraro Building                        LD  ...         None
# LADWP - Haynes Power Plant                         None  ...         None
# LADWP - Harbor Generating Station                  None  ...         None
# ...                                                 ...  ...          ...
# DELANO CHEVY STATION 4                             None  ...         None
# DELANO CHEVY STATION 5                             None  ...         None
# DELANO CHEVY STATION 6                             None  ...         None
# SCT PARKING SCT EV CHARGER                         None  ...         None
# Santa Fe Springs Marketplace                       None  ...         None
#
#                                   rd_max_biodiesel_level nps_unit_name  \
# station_name
# LADWP - Truesdale Center                            None          None
# Los Angeles Convention Center                       None          None
# LADWP - John Ferraro Building                       None          None
# LADWP - Haynes Power Plant                          None          None
# LADWP - Harbor Generating Station                   None          None
# ...                                                  ...           ...
# DELANO CHEVY STATION 4                              None          None
# DELANO CHEVY STATION 5                              None          None
# DELANO CHEVY STATION 6                              None          None
# SCT PARKING SCT EV CHARGER                          None          None
# Santa Fe Springs Marketplace                        None          None
#
#                                   access_days_time_fr  \
# station_name
# LADWP - Truesdale Center                         None
# Los Angeles Convention Center                    None
# LADWP - John Ferraro Building                    None
# LADWP - Haynes Power Plant                       None
# LADWP - Harbor Generating Station                None
# ...                                               ...
# DELANO CHEVY STATION 4                           None
# DELANO CHEVY STATION 5                           None
# DELANO CHEVY STATION 6                           None
# SCT PARKING SCT EV CHARGER                       None
# Santa Fe Springs Marketplace                     None
#
#                                   intersection_directions_fr bd_blends_fr  \
# station_name
# LADWP - Truesdale Center                                None         None
# Los Angeles Convention Center                           None         None
# LADWP - John Ferraro Building                           None         None
# LADWP - Haynes Power Plant                              None         None
# LADWP - Harbor Generating Station                       None         None
# ...                                                      ...          ...
# DELANO CHEVY STATION 4                                  None         None
# DELANO CHEVY STATION 5                                  None         None
# DELANO CHEVY STATION 6                                  None         None
# SCT PARKING SCT EV CHARGER                              None         None
# Santa Fe Springs Marketplace                            None         None
#
#                                          groups_with_access_code_fr  \
# station_name
# LADWP - Truesdale Center                                      Privé
# Los Angeles Convention Center                                Public
# LADWP - John Ferraro Building                                 Privé
# LADWP - Haynes Power Plant                                    Privé
# LADWP - Harbor Generating Station                             Privé
# ...                                                             ...
# DELANO CHEVY STATION 4                                       Public
# DELANO CHEVY STATION 5             TEMPORAIREMENT SUSPENDU (Public)
# DELANO CHEVY STATION 6                                       Public
# SCT PARKING SCT EV CHARGER                                   Public
# Santa Fe Springs Marketplace                                 Public
#
#                                   ev_pricing_fr  \
# station_name
# LADWP - Truesdale Center                   None
# Los Angeles Convention Center              None
# LADWP - John Ferraro Building              None
# LADWP - Haynes Power Plant                 None
# LADWP - Harbor Generating Station          None
# ...                                         ...
# DELANO CHEVY STATION 4                     None
# DELANO CHEVY STATION 5                     None
# DELANO CHEVY STATION 6                     None
# SCT PARKING SCT EV CHARGER                 None
# Santa Fe Springs Marketplace               None
#
#                                                                       ev_network_ids  \
# station_name
# LADWP - Truesdale Center                                                         NaN
# Los Angeles Convention Center                                                    NaN
# LADWP - John Ferraro Building                                                    NaN
# LADWP - Haynes Power Plant                                                       NaN
# LADWP - Harbor Generating Station                                                NaN
# ...                                                                              ...
# DELANO CHEVY STATION 4             {'station': ['USCPIL16231861'], 'posts': ['259...
# DELANO CHEVY STATION 5             {'station': ['USCPIL16231981'], 'posts': ['259...
# DELANO CHEVY STATION 6             {'station': ['USCPIL16232041'], 'posts': ['259...
# SCT PARKING SCT EV CHARGER         {'station': ['USCPIL16404281'], 'posts': ['261...
# Santa Fe Springs Marketplace       {'station': ['69061'], 'posts': ['148087', '14...
#
#                                    federal_agency
# station_name
# LADWP - Truesdale Center                      NaN
# Los Angeles Convention Center                 NaN
# LADWP - John Ferraro Building                 NaN
# LADWP - Haynes Power Plant                    NaN
# LADWP - Harbor Generating Station             NaN
# ...                                           ...
# DELANO CHEVY STATION 4                        NaN
# DELANO CHEVY STATION 5                        NaN
# DELANO CHEVY STATION 6                        NaN
# SCT PARKING SCT EV CHARGER                    NaN
# Santa Fe Springs Marketplace                  NaN
#
# [18670 rows x 73 columns]

# %%
df.to_csv('ev_data.csv')
